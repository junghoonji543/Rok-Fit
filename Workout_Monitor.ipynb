# %%
pip install -U ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (8.3.240)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: polars>=0.20.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.36.1)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: torch!=2.4.0,>=1.8.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.9.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\dydhd\appdata\roaming\python\python310\site-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (3.10.7)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (0.24.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: cycler>=0.10 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dydhd\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dydhd\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: polars-runtime-32==1.36.1 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from polars>=0.20.0->ultralytics) (1.36.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (2025.12.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\dydhd\appdata\roaming\python\python310\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: filelock in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (3.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\dydhd\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch!=2.4.0,>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dydhd\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch!=2.4.0,>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import ultralytics
from ultralytics import solutions
from ultralytics.utils.downloads import safe_download

# !apt-get install -y ffmpeg  # for video writing properly
ultralytics.checks()
# Out:
# Ultralytics 8.3.240  Python-3.10.11 torch-2.9.1+cpu CPU (AMD Ryzen 9 8940HX with Radeon Graphics)
# Setup complete  (32 CPUs, 31.1 GB RAM, 250.3/952.8 GB disk)

# %%
exercises_list = ["Legextension", "Legpress", "Squats", "Pushups"]

for exercise in exercises_list:
    safe_download(f"https://github.com/ultralytics/assets/releases/download/v0.0.0/{exercise}.demo.video.mp4")

# %%
# cap = cv2.VideoCapture("front.mp4")
cap = cv2.VideoCapture(r"C:\Users\dydhd\OneDrive\Desktop\Workout_Monitoring\front.mp4")
assert cap.isOpened(), "Error reading video file"

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("front.output.mp4", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init AIGym
gym = solutions.AIGym(
    show=True,  # Display the frame
    kpts=[5, 7, 9],  # keypoints index of person for monitoring specific exercise, by default it's for pushup
    model="yolo11n-pose.pt",  # Path to the YOLO11 pose estimation model file
    line_width=4,  # Adjust the line width for bounding boxes and text display
    verbose=False,
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    results = gym(im0)  # monitor workouts on each frame
    video_writer.write(results.plot_im)  # write the output frame in file.

video_writer.release()
# Out:
# Ultralytics Solutions:  {'source': None, 'model': 'yolo11n-pose.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [5, 7, 9], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 4, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': False, 'data': 'images'}
# Video frame is empty or video processing has been successfully completed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# 1단계에서 복사한 주소를 여기에 붙여넣으세요 
real_path = r"C:\Users\dydhd\OneDrive\Desktop\Workout_Monitoring\front.mp4" 

cap = cv2.VideoCapture(real_path)

if cap.isOpened():
    print("성공! 영상을 불러왔습니다.")
else:
    print("실패: 경로가 여전히 틀립니다.")
# Out:
# 성공! 영상을 불러왔습니다.

# %%
cap = cv2.VideoCapture("Squats.demo.video.mp4")
assert cap.isOpened(), "Error reading video file"

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("Squats.demo.video.output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init AIGym
gym = solutions.AIGym(
    show=True,  # Display the frame
    kpts=[5, 11, 13],  # keypoints index of person for monitoring specific exercise, by default it's for pushup
    model="yolo11m-pose.pt",  # Path to the YOLO11 pose estimation model file
    line_width=4,  # Adjust the line width for bounding boxes and text display
    verbose=False,
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    results = gym(im0)  # monitor workouts on each frame
    video_writer.write(results.plot_im)  # write the output frame in file.

video_writer.release()
# Out:
# Ultralytics Solutions:  {'source': None, 'model': 'yolo11m-pose.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [5, 11, 13], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 4, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': False, 'data': 'images'}
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m-pose.pt to 'yolo11m-pose.pt': 100% ━━━━━━━━━━━━ 40.5MB 49.9MB/s 0.8s 0.8s<0.0s
# Video frame is empty or video processing has been successfully completed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
